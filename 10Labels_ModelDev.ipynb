# %% [markdown]
# # Model Development

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CTG = pd.read_csv("data/CTG_clean.csv")

# %%
pd.set_option('display.max_columns',None)

# %%
CTG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2115 entries, 0 to 2114
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FHR_Baseline          2115 non-null   float64
#  1   Accelerations         2115 non-null   float64
#  2   Fetal_Movements       2115 non-null   float64
#  3   Uterine_Contractions  2115 non-null   float64
#  4   Light_Decels          2115 non-null   float64
#  5   Severe_Decels         2115 non-null   float64
#  6   Prolonged_Decels      2115 non-null   float64
#  7   Abnormal_STV_Percent  2115 non-null   float64
#  8   STV_Mean              2115 non-null   float64
#  9   Abnormal_LTV_Percent  2115 non-null   float64
#  10  LTV_Mean              2115 non-null   float64
#  11  Hist_Width            2115 non-null   float64
#  12  Hist_Min              2115 non-null   float64
#  13  Hist_Max              2115 non-null   float64
#  14  Hist_Peaks            2115 non-null   float64
#  15  Hist_Zeros            2115 non-null   float64
#  16  Hist_Mode             2115 non-null   float64
#  17  Hist_Mean             2115 non-null   float64
#  18  Hist_Median           2115 non-null   float64
#  19  Hist_Variance         2115 non-null   float64
#  20  Hist_Tendency         2115 non-null   float64
#  21  FHR_Class             2115 non-null   float64
#  22  Fetal_State           2115 non-null   float64
# dtypes: float64(23)
# memory usage: 380.2 KB

# %%
ints= ["FHR_Baseline", "Hist_Peaks", "Hist_Zeros", "FHR_Class", "Fetal_State"]
for column in ints:
    CTG[column] = CTG[column].astype("int64")

CTG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2115 entries, 0 to 2114
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FHR_Baseline          2115 non-null   int64
#  1   Accelerations         2115 non-null   float64
#  2   Fetal_Movements       2115 non-null   float64
#  3   Uterine_Contractions  2115 non-null   float64
#  4   Light_Decels          2115 non-null   float64
#  5   Severe_Decels         2115 non-null   float64
#  6   Prolonged_Decels      2115 non-null   float64
#  7   Abnormal_STV_Percent  2115 non-null   float64
#  8   STV_Mean              2115 non-null   float64
#  9   Abnormal_LTV_Percent  2115 non-null   float64
#  10  LTV_Mean              2115 non-null   float64
#  11  Hist_Width            2115 non-null   float64
#  12  Hist_Min              2115 non-null   float64
#  13  Hist_Max              2115 non-null   float64
#  14  Hist_Peaks            2115 non-null   int64
#  15  Hist_Zeros            2115 non-null   int64
#  16  Hist_Mode             2115 non-null   float64
#  17  Hist_Mean             2115 non-null   float64
#  18  Hist_Median           2115 non-null   float64
#  19  Hist_Variance         2115 non-null   float64
#  20  Hist_Tendency         2115 non-null   float64
#  21  FHR_Class             2115 non-null   int64
#  22  Fetal_State           2115 non-null   int64
# dtypes: float64(18), int64(5)
# memory usage: 380.2 KB

# %%
X = CTG.drop(columns =["FHR_Class","Fetal_State"])
X.describe().T
# Out:
#                        count        mean        std    min      25%      50%  \
# FHR_Baseline          2115.0  133.301655   9.836399  106.0  126.000  133.000
# Accelerations         2115.0    0.003186   0.003870    0.0    0.000    0.002
# Fetal_Movements       2115.0    0.009508   0.046783    0.0    0.000    0.000
# Uterine_Contractions  2115.0    0.004385   0.002941    0.0    0.002    0.005
# Light_Decels          2115.0    0.001899   0.002965    0.0    0.000    0.000
# Severe_Decels         2115.0    0.000003   0.000057    0.0    0.000    0.000
# Prolonged_Decels      2115.0    0.000159   0.000591    0.0    0.000    0.000
# Abnormal_STV_Percent  2115.0   46.977778  17.180933   12.0   32.000   49.000
# STV_Mean              2115.0    1.335035   0.884111    0.2    0.700    1.200
# Abnormal_LTV_Percent  2115.0    9.789598  18.329675    0.0    0.000    0.000
# LTV_Mean              2115.0    8.170922   5.632455    0.0    4.600    7.400
# Hist_Width            2115.0   70.511111  38.997589    3.0   37.000   68.000
# Hist_Min              2115.0   93.574468  29.550040   50.0   67.000   93.000
# Hist_Max              2115.0  164.085579  17.943983  122.0  152.000  162.000
# Hist_Peaks            2115.0    4.075650   2.951027    0.0    2.000    4.000
# Hist_Zeros            2115.0    0.325296   0.707507    0.0    0.000    0.000
# Hist_Mode             2115.0  137.448227  16.398956   60.0  129.000  139.000
# Hist_Mean             2115.0  134.596217  15.607096   73.0  125.000  136.000
# Hist_Median           2115.0  138.084161  14.476729   77.0  129.000  139.000
# Hist_Variance         2115.0   18.891726  29.029413    0.0    2.000    7.000
# Hist_Tendency         2115.0    0.318676   0.611005   -1.0    0.000    0.000
#
#                           75%      max
# FHR_Baseline          140.000  160.000
# Accelerations           0.006    0.019
# Fetal_Movements         0.003    0.481
# Uterine_Contractions    0.007    0.015
# Light_Decels            0.003    0.015
# Severe_Decels           0.000    0.001
# Prolonged_Decels        0.000    0.005
# Abnormal_STV_Percent   61.000   87.000
# STV_Mean                1.700    7.000
# Abnormal_LTV_Percent   11.000   91.000
# LTV_Mean               10.800   50.700
# Hist_Width            100.000  180.000
# Hist_Min              120.000  159.000
# Hist_Max              174.000  238.000
# Hist_Peaks              6.000   18.000
# Hist_Zeros              0.000   10.000
# Hist_Mode             148.000  187.000
# Hist_Mean             145.000  182.000
# Hist_Median           148.000  186.000
# Hist_Variance          24.000  269.000
# Hist_Tendency           1.000    1.000

# %% [markdown]
# I want to discover creating two models: one with 3 labels and one with 10 labels. Therefore we define two y variables.

# %%
y3 = CTG["Fetal_State"]
y10 = CTG["FHR_Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y3, test_size =
